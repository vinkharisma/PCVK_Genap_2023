# %% [markdown]
# <a href="https://colab.research.google.com/github/vinkharisma/PCVK_Genap_2023/blob/main/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TUGAS PRAKTIKUM

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 1. Buat Gamma Correction sesuai dengan petunjuk berikut
#
# Percobaan ini akan meminta anda membuat Gamma Correction. Pada percobaan ini, nilai Gamma akan diset dengan meminta masukan dari pengguna. Berikut adalah kode untuk meminta masukan nilai dari pengguna. Lanjutkan kode tersebut dengan membuat image dengan gamma correction sesuai rumus yang telah diberikan.

# %%
print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
  gamma = int(input('Masukkan nilai Gamma: '))
except ValueError:
    print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK/Images/female.tiff')

gamma_image = np.zeros(original.shape,original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      gamma_image[y,x,c] = np.clip(255 * pow (original[y,x,c] / 255, (1 / gamma)), 0, 255)

final_frame = cv.hconcat((original, gamma_image))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F7962F29E50>

# %% [markdown]
# 2

# %%
bit_depth = 2
level = 255 / (pow(2, bit_depth) - 1)

original = cv.imread('/content/drive/MyDrive/PCVK/Images/female.tiff', cv.IMREAD_GRAYSCALE)

depth_image = np.zeros(original.shape, original.dtype)

for i in range(original.shape[0]):
  for j in range(original.shape[1]):
    depth_image[i,j] = int(round(original[i,j] / level)) * level

final_frame = cv.hconcat((original, depth_image))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=L size=512x256 at 0x7F7962F29760>

# %% [markdown]
# 3

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/Images/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK/Images/noises/*.jpg'):
    n = cv.imread(img)
    cv_img.append(n)

dst = cv_img[0]
noise_number = 4 
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed): 
  mse = np.mean((original - compressed)**2) 
  if(mse == 0):  
    return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah None (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F7953464AC0>

# %%
# Jumlah Citra di Average 5
dst = cv_img[0]
noise_number = 4
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.536558044026485 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F7953449670>

# %%
# Jumlah Citra di Average 30
dst = cv_img[0]
noise_number = 29

for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.516148817141712 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F7962F50070>

# %%
# Jumlah Citra di Average 60
dst = cv_img[0]
noise_number = 59

for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.492202247017875 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F7953449520>

# %%
# Jumlah Citra di Average 80
dst = cv_img[0]
noise_number = 79

for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.50678950100513 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F796318C2B0>

# %%
# Jumlah Citra di Average 100
dst = cv_img[0]
noise_number = 99

for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.514477048227917 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7F79534BF7F0>

# %% [markdown]
# 4. Buat image masking untuk image berikut. Image kiri adalah image asli (images/couple.tiff), sedangkan image paling kanan adalah hasilnya:

# %%
original =cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

mask_image = np.zeros(original.shape, dtype=np.uint8)

mask_image = cv.circle(mask_image, (70,45), 40, (255,255,255), -1)

result = original & mask_image 

mask_image1 = cv.circle(mask_image, (195,45), 40, (255,255,255), -1)

result = original & mask_image1

org_frame = cv.hconcat((original, mask_image, result))
cv2_imshow(org_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7F7952D42F70>

# %% [markdown]
# 5. Lakukan percobaan menggunakan operator lain dan tunjukkan hasilnya pada modul ini. Tuliskan hasil analisa anda kenapa citra keluarannya seperti itu.

# %%
couple_image =cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

mask_image = np.zeros(original.shape, dtype=np.uint8)

mask_image = cv.circle(mask_image, (70,45), 40, (255,255,255), -1)
mask_image1 = cv.circle(mask_image, (195,45), 40, (255,255,255), -1)

result = couple_image | mask_image

couple_frame = cv.hconcat((couple_image, mask_image, result))
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7F7952E070D0>

# %%
couple_image =cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

mask_image = np.zeros(couple_image.shape, dtype=np.uint8)
mask_image = cv.circle(mask_image, (70,45), 40, (255,255,255), -1)
mask_image1 = cv.circle(mask_image, (195,45), 40, (255,255,255), -1)

result = ~couple_image & ~mask_image

couple_frame = cv.hconcat((couple_image, mask_image, result))
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7F7952D42D00>

# %%
couple_image =cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

mask_image = np.zeros(couple_image.shape, dtype=np.uint8)
mask_image = cv.circle(mask_image, (70,45), 40, (255,255,255), -1)
mask_image1 = cv.circle(mask_image, (195,45), 40, (255,255,255), -1)

result = ~couple_image & mask_image

couple_frame = cv.hconcat((couple_image, mask_image, result))
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7F7952E7EA90>

# %%
couple_image =cv.imread('/content/drive/MyDrive/PCVK/Images/couple.tiff')

mask = np.zeros(couple_image.shape, dtype=np.uint8)
mask_image = cv.circle(mask_image, (70,45), 40, (255,255,255), -1)
mask_image1 = cv.circle(mask_image, (195,45), 40, (255,255,255), -1)

result = couple_image ^ mask

couple_frame = cv.hconcat((couple_image, mask, result))
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256 at 0x7F7952F0AD30>
